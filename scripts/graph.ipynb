# %% [markdown]
# Visualize the complete LangGraph graph

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

from scheduler_app.graph.builder import graph


def show_graph() -> None:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(
                draw_method=MermaidDrawMethod.API,
            )
        )
    )

show_graph()
# Out:
# c:\Users\Vitus\OneDrive\Desktop\event-scheduler\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
