# %% [markdown]
# # Visualize the complete LangGraph graph

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

from my_graph.agent import graph


display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 10
#       2 from langchain_core.runnables.graph import MermaidDrawMethod
#       4 from my_graph.agent import graph
#       7 display(
#       8     Image(
#       9         graph.get_graph().draw_mermaid_png(
# ---> 10             draw_method=MermaidDrawMethod.local,
#      11         )
#      12     )
#      13 )
#
# AttributeError: type object 'MermaidDrawMethod' has no attribute 'local'
